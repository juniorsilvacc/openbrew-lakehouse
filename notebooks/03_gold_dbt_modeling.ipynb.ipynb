# %%
# Instala a ferramenta
# %pip install dbt-databricks

# %%
# %sh

# Verifica a instalação
dbt --version

# %%
# %sh 

# Baixa as ferramentas auxiliares (deps)
cd /Workspace/projetos/openbrew-lakehouse/dbt_gold && dbt deps

# %%
# %sh
 
# Testa se a "ponte" está em pé (debug)
cd /Workspace/projetos/openbrew-lakehouse/dbt_gold && dbt debug --profiles-dir .

# %%
# %sh 

# Executa a construção das tabelas (run)
cd /Workspace/projetos/openbrew-lakehouse/dbt_gold && dbt run --profiles-dir .

# %%
# %sh

# Execução dos testes de qualidade
cd /Workspace/projetos/openbrew-lakehouse/dbt_gold && dbt test

# %%
# %sql
SELECT * FROM openbrew.brew_staging.stg_brew LIMIT 10;
